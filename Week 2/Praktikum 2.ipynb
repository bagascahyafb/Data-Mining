# %% [markdown]
# # Live Coding with Pak Pras

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# ### Menampilkan Dataset

# %%
west_df = pd.read_csv('WestRoxbury.csv')
west_df
# Out:
#       TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA  \
# 0            344.2  4330       9965      1880         2436         1352
# 1            412.6  5190       6590      1945         3108         1976
# 2            330.1  4152       7500      1890         2294         1371
# 3            498.6  6272      13773      1957         5032         2608
# 4            331.5  4170       5000      1910         2370         1438
# ...            ...   ...        ...       ...          ...          ...
# 5797         404.8  5092       6762      1938         2594         1714
# 5798         407.9  5131       9408      1950         2414         1333
# 5799         406.5  5113       7198      1987         2480         1674
# 5800         308.7  3883       6890      1946         2000         1000
# 5801         447.6  5630       7406      1950         2510         1600
#
#       FLOORS   ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE  \
# ...

# %%
west_df.shape
# Out:
# (5802, 14)

# %%
west_df.head()
# Out:
#    TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA  FLOORS   \
# 0         344.2  4330       9965      1880         2436         1352      2.0
# 1         412.6  5190       6590      1945         3108         1976      2.0
# 2         330.1  4152       7500      1890         2294         1371      2.0
# 3         498.6  6272      13773      1957         5032         2608      1.0
# 4         331.5  4170       5000      1910         2370         1438      2.0
#
#    ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE REMODEL
# 0      6          3          1          1        1          0    None
# 1     10          4          2          1        1          0  Recent
# 2      8          4          1          1        1          0    None
# 3      9          5          1          1        1          1    None
# 4      7          3          2          0        1          0    None

# %% [markdown]
# ### Cek Kolom

# %%
west_df.columns
# Out:
# Index(['TOTAL VALUE ', 'TAX', 'LOT SQFT ', 'YR BUILT', 'GROSS AREA ',
#        'LIVING AREA', 'FLOORS ', 'ROOMS', 'BEDROOMS ', 'FULL BATH',
#        'HALF BATH', 'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %% [markdown]
# ### Ganti Nama Kolom

# %%
west_df = west_df.rename(columns={'TOTAL VALUE ' : 'TOTAL_VALUE'})
west_df.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT SQFT ', 'YR BUILT', 'GROSS AREA ',
#        'LIVING AREA', 'FLOORS ', 'ROOMS', 'BEDROOMS ', 'FULL BATH',
#        'HALF BATH', 'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
west_df.columns = [i.strip().replace(' ', '_') for i in west_df.columns]
west_df.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT_SQFT', 'YR_BUILT', 'GROSS_AREA',
#        'LIVING_AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL_BATH', 'HALF_BATH',
#        'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %% [markdown]
# ### Mengakses Subset

# %%
west_df.loc[0:3]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0    None
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0    None
# 3      9         5          1          1        1          1    None

# %%
west_df.iloc[0:4]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0    None
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0    None
# 3      9         5          1          1        1          1    None

# %%
west_df["TOTAL_VALUE"].iloc[0:10]
# Out:
# 0    344.2
# 1    412.6
# 2    330.1
# 3    498.6
# 4    331.5
# 5    337.4
# 6    359.4
# 7    320.4
# 8    333.5
# 9    409.4
# Name: TOTAL_VALUE, dtype: float64

# %%
west_df.iloc[0:10]['TOTAL_VALUE']
# Out:
# 0    344.2
# 1    412.6
# 2    330.1
# 3    498.6
# 4    331.5
# 5    337.4
# 6    359.4
# 7    320.4
# 8    333.5
# 9    409.4
# Name: TOTAL_VALUE, dtype: float64

# %% [markdown]
# ### Manipulasi Data

# %%
west_df.iloc[4, :10]
# Out:
# TOTAL_VALUE    331.5
# TAX             4170
# LOT_SQFT        5000
# YR_BUILT        1910
# GROSS_AREA      2370
# LIVING_AREA     1438
# FLOORS           2.0
# ROOMS              7
# BEDROOMS           3
# FULL_BATH          2
# Name: 4, dtype: object

# %%
west_df.iloc[4:5, 0:10]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 4        331.5  4170      5000      1910        2370         1438     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH
# 4      7         3          2

# %%
pd.concat([west_df.iloc[4:6, 0:2], west_df.iloc[4:6, 4:6]], axis = 1)
# Out:
#    TOTAL_VALUE   TAX  GROSS_AREA  LIVING_AREA
# 4        331.5  4170        2370         1438
# 5        337.4  4244        2124         1060

# %% [markdown]
# ### Statistik

# %%
print("Sejumlah Baris : ", len(west_df['TOTAL_VALUE']))
print("Nilai Mean : ", west_df['TOTAL_VALUE'].mean())
# Out:
# Sejumlah Baris :  5802
# Nilai Mean :  392.6857149258877

# %%
west_df["TOTAL_VALUE"].describe()
# Out:
# count    5802.000000
# mean      392.685715
# std        99.177414
# min       105.000000
# 25%       325.125000
# 50%       375.900000
# 75%       438.775000
# max      1217.800000
# Name: TOTAL_VALUE, dtype: float64

# %%
west_df.describe()
# Out:
#        TOTAL_VALUE           TAX      LOT_SQFT     YR_BUILT   GROSS_AREA  \
# count  5802.000000   5802.000000   5802.000000  5802.000000  5802.000000
# mean    392.685715   4939.485867   6278.083764  1936.744916  2924.842123
# std      99.177414   1247.649118   2669.707974    35.989910   883.984726
# min     105.000000   1320.000000    997.000000     0.000000   821.000000
# 25%     325.125000   4089.500000   4772.000000  1920.000000  2347.000000
# 50%     375.900000   4728.000000   5683.000000  1935.000000  2700.000000
# 75%     438.775000   5519.500000   7022.250000  1955.000000  3239.000000
# max    1217.800000  15319.000000  46411.000000  2011.000000  8154.000000
#
#        LIVING_AREA       FLOORS        ROOMS     BEDROOMS    FULL_BATH  \
# count  5802.000000  5802.000000  5802.000000  5802.000000  5802.000000
# mean   1657.065322     1.683730     6.994829     3.230093     1.296794
# std     540.456726     0.444884     1.437657     0.846607     0.522040
# ...

# %% [markdown]
# ### Sampling Data

# %%
west_df.sample(5)
# Out:
#       TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 5262        438.7  5518      4789      1910        2976         1680     2.0
# 4084        551.6  6939     14050      1910        5259         2921     2.0
# 2614        303.9  3823      3643      1930        2333         1344     2.0
# 842         316.0  3975      4574      1915        4456         2044     1.0
# 4560        450.1  5662      5400      1931        3512         2013     2.0
#
#       ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 5262      7         3          2          1        1          0    None
# 4084     10         4          1          0        1          2    None
# 2614      6         3          1          0        1          0    None
# 842       8         4          1          1        1          0    None
# 4560      7         4          2          1        1          1     Old

# %%
weight = [0.9 if rows > 10 else 0.01 for rows in west_df.ROOMS]
west_df.sample(10, weights=weight)
# Out:
#       TOTAL_VALUE    TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 4329       698.10   8782      6800      1908        5031         3461     2.0
# 4697       475.70   5984      5800      1890        3736         2184     2.0
# 3475       351.20   4418      6009      1929        3952         2128     2.0
# 2183       716.20   9009      9022      1920        4758         3132     2.0
# 3850       410.80   5167      5293      1900        3948         2071     2.0
# 3389       574.70   7229      8994      1900        5897         3491     2.0
# 5447       603.36   7590      8945      1950        4952         2827     2.0
# 686        500.00   6290      8000      1966        4400         3494     1.0
# 5220       447.90   5634      5000      1920        3917         2012     2.0
# 3164       873.00  10982     19630      1910        6565         3374     2.0
#
#       ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# ...

# %% [markdown]
# ### Modeling Data

# %%
west_df.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT_SQFT', 'YR_BUILT', 'GROSS_AREA',
#        'LIVING_AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL_BATH', 'HALF_BATH',
#        'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
west_df.dtypes
# Out:
# TOTAL_VALUE    float64
# TAX              int64
# LOT_SQFT         int64
# YR_BUILT         int64
# GROSS_AREA       int64
# LIVING_AREA      int64
# FLOORS         float64
# ROOMS            int64
# BEDROOMS         int64
# FULL_BATH        int64
# HALF_BATH        int64
# KITCHEN          int64
# FIREPLACE        int64
# REMODEL         object
# dtype: object

# %%
print(west_df.REMODEL.dtypes)
west_df.REMODEL = west_df.REMODEL.astype('category')
print(west_df.REMODEL.cat.categories)
print(west_df.REMODEL.dtypes)
# Out:
# object
# Index(['None', 'Old', 'Recent'], dtype='object')
# category

# %%
print("Data Valid - Before :", west_df['BEDROOMS'].count())
missingRows = west_df.sample(10).index
west_df.loc[missingRows, ['BEDROOMS']] = np.nan

print("Data Valid - After NaN :", west_df['BEDROOMS'].count())
west_df["BEDROOMS"].count()
# Out:
# Data Valid - Before : 5802
# Data Valid - After NaN : 5792
# 5792

# %%
reduce_df = west_df.dropna()
print("Data Valid - After DROP NaN :", len(reduce_df))
# Out:
# Data Valid - After DROP NaN : 5792

# %%
medianBedroom = west_df["BEDROOMS"].median()
print("Data Valid - Nilai Median :", medianBedroom)

west_df.BEDROOMS = west_df.BEDROOMS.fillna(value=medianBedroom)
print("Data Valid - After Median :", west_df['BEDROOMS'].count())
# Out:
# Data Valid - Nilai Median : 3.0
# Data Valid - After Median : 5802

# %% [markdown]
# ## Data Visualisation

# %%
import os
import numpy as np
import networkx as nx
import pandas as pd
from pandas.plotting import scatter_matrix, parallel_coordinates
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
boston_df = pd.read_csv("BostonHousing.csv")
boston_df = boston_df.rename(columns= {"CAT. MEDV" : 'CAT_MEDV'})
boston_df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV  CAT_MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# ...

# %%
boston_df.plot.scatter(x = 'LSTAT', y = 'MEDV', legend = False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()
fig.set_size_inches(5, 3)

ax.scatter(boston_df.LSTAT, boston_df.MEDV, color='C2', facecolor='None')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')

plt.tight_layout()
plt.show()

# %%
ax = boston_df.groupby('CHAS').mean().MEDV.plot(kind='bar', figsize=[5,3])
ax.set_ylabel("AVG MEDV")
plt.tight_layout()
plt.show()

# %%
dataplot = boston_df.groupby('CHAS').mean().MEDV
fig, ax = plt.subplots()
ax.bar(dataplot.index, dataplot, color=['C5', 'C1'])
ax.set_xticks([0,1])

ax.set_xlabel("CHAS")
ax.set_ylabel("AVG MEDV")

plt.show()

# %%
df = pd.read_csv('Amtrak.csv')
df.head()
# Out:
#         Month  Ridership
# 0  01/01/1991   1708.917
# 1  01/02/1991   1620.586
# 2  01/03/1991   1972.715
# 3  01/04/1991   1811.665
# 4  01/05/1991   1974.964

# %%
df['Date'] = pd.to_datetime(df.Month, format='%d/%m/%Y')
ridership = pd.Series(df.Ridership.values, index = df.Date)
df.head()
# Out:
#         Month  Ridership       Date
# 0  01/01/1991   1708.917 1991-01-01
# 1  01/02/1991   1620.586 1991-02-01
# 2  01/03/1991   1972.715 1991-03-01
# 3  01/04/1991   1811.665 1991-04-01
# 4  01/05/1991   1974.964 1991-05-01

# %%
ridership.plot(ylim = [1200, 2500], legend = False, figsize=[5,3])
plt.xlabel('Year')
plt.ylabel('Ridership')

plt.tight_layout
plt.show()

# %%
plt.plot(ridership.index, ridership)
plt.xlabel('Year')
plt.ylabel('Ridership')

plt.show()

# %%
ax = boston_df.MEDV.hist()
plt.xlabel("MEDV")
plt.ylabel("COUNT")

plt.show()

# %%
ax = boston_df.boxplot(column='MEDV', by='CHAS')

ax.set_ylabel("MEDV")
plt.suptitle('')
plt.title('')
plt.show()

# %%
corr = boston_df.corr()

fig, ax = plt.subplots()
fig.set_size_inches(11, 7)

sns.heatmap(corr, annot=True, fmt='.1f', cmap='RdBu', center=0, ax = ax)
plt.show()

# %%
_ = scatter_matrix(boston_df[['CRIM', 'INDUS', 'LSTAT', 'MEDV']],figsize=(6,6), diagonal='kde')

# %% [markdown]
# ### Ilustrasi visualisasi jaringan

# %%
ebay_df = pd.read_csv('eBayNetwork.csv')

G = nx.from_pandas_edgelist(ebay_df, source='Seller', target='Bidder')

isibidder = [i in set(ebay_df.Bidder) for i in G.nodes()]
pos = nx.spring_layout(G, k = 0.13, iterations=60, scale=0.5)

plt.figure(figsize=[10,10])
nx.draw_networkx(G, pos=pos, with_labels=False, edge_color='lightgray', 
node_color=['gray' if bidder else 'black' for bidder in isibidder], 
node_size=[50 if bidder else 200 for bidder in isibidder])

plt.axis('off')
plt.show()
